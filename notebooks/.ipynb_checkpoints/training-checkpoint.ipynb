# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import random
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split 
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
np.random.seed(0)

# %%
df = pd.read_csv('/data/CarPrice.csv')
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration  \
# 0       1          3        alfa-romero giulia      gas        std
# 1       2          3       alfa-romero stelvio      gas        std
# 2       3          1  alfa-romero Quadrifoglio      gas        std
# 3       4          2               audi 100 ls      gas        std
# 4       5          2                audi 100ls      gas        std
#
#        carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 0  convertible        rwd          front       88.6      168.8  ...
# 1  convertible        rwd          front       88.6      168.8  ...
# 2    hatchback        rwd          front       94.5      171.2  ...
# 3        sedan        fwd          front       99.8      176.6  ...
# 4        sedan        4wd          front       99.4      176.6  ...
#
#    enginesize  fuelsystem  boreratio stroke compressionratio  horsepower  \
# 0         130        mpfi       3.47   2.68              9.0         111
# ...

# %%
df.drop(['car_ID'],axis=1,inplace = True)

# %%
brand = df['CarName'].apply(lambda x : x.split(' ')[0])

# %%
df.insert(3,"brand",brand)

# %%
df.drop('CarName',axis = 1,inplace=True)

# %%
df.head()
# Out:
#    symboling fueltype        brand aspiration      carbody drivewheel  \
# 0          3      gas  alfa-romero        std  convertible        rwd
# 1          3      gas  alfa-romero        std  convertible        rwd
# 2          1      gas  alfa-romero        std    hatchback        rwd
# 3          2      gas         audi        std        sedan        fwd
# 4          2      gas         audi        std        sedan        4wd
#
#   enginelocation  wheelbase  carlength  carwidth  ...  enginesize  fuelsystem  \
# 0          front       88.6      168.8      64.1  ...         130        mpfi
# 1          front       88.6      168.8      64.1  ...         130        mpfi
# 2          front       94.5      171.2      65.5  ...         152        mpfi
# 3          front       99.8      176.6      66.2  ...         109        mpfi
# 4          front       99.4      176.6      66.4  ...         136        mpfi
#
# ...

# %%
df.select_dtypes(include=['object'])
# Out:
#     fueltype        brand aspiration      carbody drivewheel enginelocation  \
# 0        gas  alfa-romero        std  convertible        rwd          front
# 1        gas  alfa-romero        std  convertible        rwd          front
# 2        gas  alfa-romero        std    hatchback        rwd          front
# 3        gas         audi        std        sedan        fwd          front
# 4        gas         audi        std        sedan        4wd          front
# ..       ...          ...        ...          ...        ...            ...
# 200      gas        volvo        std        sedan        rwd          front
# 201      gas        volvo      turbo        sedan        rwd          front
# 202      gas        volvo        std        sedan        rwd          front
# 203   diesel        volvo      turbo        sedan        rwd          front
# 204      gas        volvo      turbo        sedan        rwd          front
#
#     enginetype cylindernumber fuelsystem
# ...

# %%
# Defining the map function
def dummies(x,df):
    temp = pd.get_dummies(df[x], drop_first = True)
    df = pd.concat([df, temp], axis = 1)
    df.drop([x], axis = 1, inplace = True)
    return df
# Applying the function to the cars_lr

df = dummies('fueltype',df)
df = dummies('aspiration',df)
df = dummies('carbody',df)
df = dummies('drivewheel',df)
df = dummies('enginetype',df)
df = dummies('cylindernumber',df)
df = dummies('brand',df)
df = dummies('enginelocation',df)
df = dummies('fuelsystem',df)

# %%
df.shape
# Out:
# (205, 70)

# %%
df.columns.values
# Out:
# array(['symboling', 'wheelbase', 'carlength', 'carwidth', 'carheight',
#        'curbweight', 'enginesize', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg',
#        'highwaympg', 'price', 'gas', 'turbo', 'hardtop', 'hatchback',
#        'sedan', 'wagon', 'fwd', 'rwd', 'dohcv', 'l', 'ohc', 'ohcf',
#        'ohcv', 'rotor', 'five', 'four', 'six', 'three', 'twelve', 'two',
#        'alfa-romero', 'audi', 'bmw', 'buick', 'chevrolet', 'dodge',
#        'honda', 'isuzu', 'jaguar', 'maxda', 'mazda', 'mercury',
#        'mitsubishi', 'nissan', 'peugeot', 'plymouth', 'porcshce',
#        'porsche', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'volvo', 'vw', 'rear', '2bbl', '4bbl',
#        'idi', 'mfi', 'mpfi', 'spdi', 'spfi'], dtype=object)

# %%
y= df.pop('price')
X= df

# %% [markdown]
# 'enginesize', 'curbweight', 'highwaympg','horsepower', 'carwidth'are the top 5 important features by random forest

# %% [markdown]
# Hyperparameter tuning for selecting the best random forest model

# %%
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200,num = 12)]
max_features = ['auto','sqrt']
max_depth = [int(x) for x in np.linspace(5,30,num = 6)]
min_samples_split = [2,5,10,15,100]
min_samples_leaf  = [1,2,5,10]
grid = {'n_estimators': n_estimators,
        'max_features': max_features,
        'max_depth': max_depth,
        'min_samples_split': min_samples_split,
       'min_samples_leaf': min_samples_leaf}
print(grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
x_train, x_test,y_train,y_test = train_test_split(X,y,random_state=0,test_size=0.2)

# %%
model = RandomForestRegressor() 
hyp = RandomizedSearchCV(estimator = model,
                        param_distributions=grid,
                        n_iter=10,
                       scoring='neg_mean_squared_error',
                        cv=5,verbose = 2,
                        random_state = 42,n_jobs = 1) 
hyp.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.8s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   1.0s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   1.0s
# ...

# %%
print('Best Score: %s' % hyp.best_score_)
print('Best Hyperparameters: %s' % hyp.best_params_)
# Out:
# Best Score: -5415432.395416978
# Best Hyperparameters: {'n_estimators': 700, 'min_samples_split': 15, 'min_samples_leaf': 1, 'max_features': 'auto', 'max_depth': 20}

# %% [markdown]
# Best Score is -5408089.372248346 with parameters 'n_estimators': 700, 'min_samples_split': 15, 'min_samples_leaf': 1, 'max_features': 'auto', 'max_depth': 20

# %%
y_pred = hyp.predict(x_test)

# %% [markdown]
# # Extracting feature importance using random forest

# %% [markdown]
# # Remodeling with imp features

# %%
rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X, y)

plt.figure(figsize=(10,12))

global_importances = pd.Series(rf.feature_importances_, index=X.columns)
global_importances.sort_values(ascending=True, inplace=True)
global_importances.plot.barh(color='green')
#plt.figure(figsize=(20,20))
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.title("Global Feature Importance - Built-in Method")

plt.show()

# %%
global_importances = pd.Series(rf.feature_importances_, index=df.columns)
global_importances.sort_values(ascending=False, inplace=True)
X_feat = global_importances[:5]
X_feat.head()
# Out:
# enginesize    0.650942
# curbweight    0.195372
# highwaympg    0.057106
# horsepower    0.018467
# carwidth      0.012782
# dtype: float64

# %%
df_impfeat = df[['enginesize', 'curbweight', 'highwaympg','horsepower', 'carwidth']]
df_impfeat.head()
# Out:
#    enginesize  curbweight  highwaympg  horsepower  carwidth
# 0         130        2548          27         111      64.1
# 1         130        2548          27         111      64.1
# 2         152        2823          26         154      65.5
# 3         109        2337          30         102      66.2
# 4         136        2824          22         115      66.4

# %%
y= y
X= df_impfeat

# %%
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200,num = 12)]
max_features = ['auto','sqrt']
max_depth = [int(x) for x in np.linspace(5,30,num = 6)]
min_samples_split = [2,5,10,15,100]
min_samples_leaf  = [1,2,5,10]
grid = {'n_estimators': n_estimators,
        'max_features': max_features,
        'max_depth': max_depth,
        'min_samples_split': min_samples_split,
       'min_samples_leaf': min_samples_leaf}
print(grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
x_train, x_test,y_train,y_test = train_test_split(X,y,random_state=0,test_size=0.2)

# %%
model = RandomForestRegressor() 
hyp = RandomizedSearchCV(estimator = model,
                        param_distributions=grid,
                        n_iter=10,
                       scoring='neg_mean_squared_error',
                        cv=5,verbose = 2,
                        random_state = 42,n_jobs = 1) 
hyp.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.8s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   1.0s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   1.1s
# ...

# %%
print('Best Score: %s' % hyp.best_score_)
print('Best Hyperparameters: %s' % hyp.best_params_)
# Out:
# Best Score: -4478904.144277452
# Best Hyperparameters: {'n_estimators': 1000, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 25}

# %%
y_pred = hyp.predict(x_test)

# %% [markdown]
# Saving model in a pickle file

# %%
import pickle
#file = open("carprice_rf.pkl", "wb") # opening a new file in write mode
#pickle.dump(hyp, file) # dumping created model into a pickle file
#file.close()
